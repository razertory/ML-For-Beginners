# %%
print('ipynb')
# Out:
# ipynb

# %% [markdown]
# 补充：
# `X, y = datasets.load_diabetes(return_X_y=True)` 方法会对每一行做缩放处理，目的是特征变量进行标准化，以确保它们具有相似的尺度和范围。

# %%
import numpy as np

n = [59, 48, 72, 24, 50, 23, 36, 66, 60, 29, 22, 56, 53, 50, 61, 34, 47, 68, 38, 41, 35, 25, 25, 61, 31, 30, 19, 42, 63, 67, 32, 42, 58, 57, 53, 62, 52, 46, 48, 48, 50, 21, 32, 54, 61, 56, 33, 27, 67, 37, 58, 65, 34, 46, 35, 37, 37, 41, 60, 66, 29, 37, 41, 39, 67, 36, 46, 60, 59, 53, 48, 48, 66, 52, 52, 46, 40, 22, 50, 20, 68, 52, 44, 38, 49, 61, 29, 61, 34, 36, 52, 61, 43, 35, 27, 29, 64, 41, 49, 48, 53, 53, 23, 65, 41, 55, 22, 56, 54, 59, 60, 54, 25, 54, 55, 40, 62, 65, 33, 53, 35, 66, 62, 50, 47, 47, 24, 58, 34, 51, 31, 22, 53, 37, 28, 47, 23, 50, 58, 55, 60, 41, 60, 40, 57, 37
, 40, 33, 32, 35, 55, 49, 39, 60, 67, 41, 44, 48, 45, 47, 46, 36, 34, 53, 61, 37, 33, 68, 49, 48, 55, 43, 60, 31, 53, 67
, 61, 62, 60, 42, 38, 62, 61, 61, 53, 28, 26, 30, 50, 48, 51, 47, 64, 51, 30, 56, 42, 62, 34, 60, 64, 39, 71, 48, 79, 40
, 49, 51, 57, 59, 51, 74, 67, 49, 57, 56, 52, 69, 37, 24, 55, 36, 42, 21, 41, 57, 20, 67, 34, 41, 38, 51, 52, 67, 61, 67
, 56, 64, 58, 55, 62, 57, 20, 53, 32, 41, 60, 26, 37, 45, 67, 34, 50, 71, 57, 49, 35, 41, 70, 52, 60, 62, 44, 28, 58, 39
, 34, 65, 66, 51, 50, 59, 52, 69, 53, 47, 52, 39, 67, 59, 51, 23, 68, 44, 60, 52, 38, 61, 68, 28, 65, 69, 51, 29, 55, 34
, 67, 49, 55, 59, 53, 48, 52, 69, 60, 46, 51, 67, 49, 46, 47, 75, 28, 65, 42, 51, 53, 54, 73, 54, 42, 75, 55, 68, 57, 48
, 61, 69, 38, 45, 51, 71, 57, 56, 32, 50, 43, 54, 31, 56, 44, 57, 64, 43, 19, 71, 50, 59, 57, 49, 41, 25, 52, 34, 42, 28
, 47, 32, 43, 59, 53, 60, 54, 35, 49, 58, 36, 46, 44, 46, 54, 63, 41, 28, 19, 61, 48, 54, 53, 48, 53, 29, 62, 50, 58, 55
, 54, 36, 63, 47, 51, 42, 37, 28, 58, 32, 25, 63, 52, 65, 42, 53, 79, 43, 44, 62, 33, 56, 66, 34, 46, 50, 69, 34, 71, 47
, 41, 34, 51, 43, 55, 59, 27, 51, 49, 27, 57, 39, 62, 37, 46, 68, 51, 41, 53, 45, 33, 60, 47, 60, 36, 36]

# 假设你有一个名为"array"的数组
array = np.array(n)

# 均值中心化
mean_centered = array - np.mean(array)

# 计算标准差
std_dev = np.std(array)

# 计算样本数量的平方根
sqrt_n_samples = np.sqrt(array.size)

# 进行缩放
scaled_array = mean_centered / (std_dev * sqrt_n_samples)

print(scaled_array)
# Out:
# [ 0.03807591 -0.00188202  0.08529891 -0.08906294  0.00538306 -0.09269548
#  -0.04547248  0.06350368  0.04170844 -0.07090025 -0.09632802  0.02717829
#   0.01628068  0.00538306  0.04534098 -0.05273755 -0.00551455  0.07076875
#  -0.0382074  -0.02730979 -0.04910502 -0.0854304  -0.0854304   0.04534098
#  -0.06363517 -0.06726771 -0.10722563 -0.02367725  0.05260606  0.06713621
#  -0.06000263 -0.02367725  0.03444337  0.03081083  0.01628068  0.04897352
#   0.01264814 -0.00914709 -0.00188202 -0.00188202  0.00538306 -0.09996055
#  -0.06000263  0.01991321  0.04534098  0.02717829 -0.05637009 -0.07816532
#   0.06713621 -0.04183994  0.03444337  0.05987114 -0.05273755 -0.00914709
#  -0.04910502 -0.04183994 -0.04183994 -0.02730979  0.04170844  0.06350368
#  -0.07090025 -0.04183994 -0.02730979 -0.03457486  0.06713621 -0.04547248
#  -0.00914709  0.04170844  0.03807591  0.01628068 -0.00188202 -0.00188202
#   0.06350368  0.01264814  0.01264814 -0.00914709 -0.03094232 -0.09632802
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, model_selection

# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.tab.txt
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.read.tab.out.txt
X, y = datasets.load_diabetes(return_X_y=True)
print(X)
print(X[0])
print(y)


X = X[:, 2] #BIM
X = X.reshape((-1,1)) 

#print(X.shape)

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33)
# Out:
# [[ 0.03807591  0.05068012  0.06169621 ... -0.00259226  0.01990749
#   -0.01764613]
#  [-0.00188202 -0.04464164 -0.05147406 ... -0.03949338 -0.06833155
#   -0.09220405]
#  [ 0.08529891  0.05068012  0.04445121 ... -0.00259226  0.00286131
#   -0.02593034]
#  ...
#  [ 0.04170844  0.05068012 -0.01590626 ... -0.01107952 -0.04688253
#    0.01549073]
#  [-0.04547248 -0.04464164  0.03906215 ...  0.02655962  0.04452873
#   -0.02593034]
#  [-0.04547248 -0.04464164 -0.0730303  ... -0.03949338 -0.00422151
#    0.00306441]]
# [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]
# [151.  75. 141. 206. 135.  97. 138.  63. 110. 310. 101.  69. 179. 185.
#  118. 171. 166. 144.  97. 168.  68.  49.  68. 245. 184. 202. 137.  85.
#  131. 283. 129.  59. 341.  87.  65. 102. 265. 276. 252.  90. 100.  55.
#   61.  92. 259.  53. 190. 142.  75. 142. 155. 225.  59. 104. 182. 128.
# ...
